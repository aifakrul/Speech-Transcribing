# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh | sudo bash
# Out:
# Detected operating system as Ubuntu/bionic.
# Checking for curl...
# Detected curl...
# Checking for gpg...
# Detected gpg...
# Running apt-get update... done.
# Installing apt-transport-https... done.
# Installing /etc/apt/sources.list.d/github_git-lfs.list...done.
# Importing packagecloud gpg key... done.
# Running apt-get update... done.
#
# The repository is setup! You can now install packages.

# %%
# !sudo apt-get install git-lfs
# !git lfs pull
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   git-lfs
# 0 upgraded, 1 newly installed, 0 to remove and 108 not upgraded.
# Need to get 6,531 kB of archives.
# After this operation, 16.1 MB of additional disk space will be used.
# Get:1 https://packagecloud.io/github/git-lfs/ubuntu bionic/main amd64 git-lfs amd64 2.10.0 [6,531 kB]
# Fetched 6,531 kB in 1s (7,759 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package git-lfs.
# ...

# %%
# !git clone https://github.com/mozilla/DeepSpeech
# Out:
# Cloning into 'DeepSpeech'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 18128 (delta 3), reused 5 (delta 2), pack-reused 18117
# Receiving objects: 100% (18128/18128), 47.55 MiB | 20.72 MiB/s, done.
# Resolving deltas: 100% (12333/12333), done.

# %%
# %cd DeepSpeech
# !pwd
# !ls
# Out:
# /content/DeepSpeech
# /content/DeepSpeech
# bazel.patch
# BIBLIOGRAPHY.md
# bin
# build-python-wheel.yml-DISABLED_ENABLE_ME_TO_REBUILD_DURING_PR
# CODE_OF_CONDUCT.md
# CONTRIBUTING.rst
# data
# DeepSpeech.py
# doc
# Dockerfile
# evaluate.py
# evaluate_tflite.py
# examples
# GRAPH_VERSION
# images
# ISSUE_TEMPLATE.md
# LICENSE
# lm_optimizer.py
# native_client
# README.rst
# RELEASE.rst
# requirements_eval_tflite.txt
# requirements_tests.txt
# requirements_transcribe.txt
# setup.py
# stats.py
# SUPPORT.rst
# taskcluster
# tests
# training
# transcribe.py
# util
# VERSION

# %%
# !pip3 install --upgrade pip==20.0.2 wheel==0.34.2 setuptools==46.1.3
# !pip3 install --upgrade --force-reinstall -e .
# Out:
# ...
#      |████████████████████████████████| 1.4MB 5.8MB/s
# Requirement already up-to-date: wheel==0.34.2 in /usr/local/lib/python3.6/dist-packages (0.34.2)
# Requirement already up-to-date: setuptools==46.1.3 in /usr/local/lib/python3.6/dist-packages (46.1.3)
# ...
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# ...
# Obtaining file:///content/DeepSpeech
# ...
#      |████████████████████████████████| 110.5 MB 31 kB/s
# ...
#      |████████████████████████████████| 20.2 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 51 kB 86 kB/s
# ...
#      |████████████████████████████████| 40 kB 6.3 MB/s
# ...
#      |████████████████████████████████| 104 kB 40.2 MB/s
# ...
#      |████████████████████████████████| 163 kB 54.8 MB/s
# ...
#      |████████████████████████████████| 10.0 MB 40.8 MB/s
# ...
#      |████████████████████████████████| 58 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 3.7 MB 41.5 MB/s
# ...

# %%
# %cd DeepSpeech
# !ls
# Out:
# /content/DeepSpeech
# bazel.patch
# BIBLIOGRAPHY.md
# bin
# build-python-wheel.yml-DISABLED_ENABLE_ME_TO_REBUILD_DURING_PR
# CODE_OF_CONDUCT.md
# CONTRIBUTING.rst
# data
# DeepSpeech.py
# doc
# Dockerfile
# evaluate.py
# evaluate_tflite.py
# examples
# GRAPH_VERSION
# images
# ISSUE_TEMPLATE.md
# LICENSE
# lm_optimizer.py
# native_client
# README.rst
# RELEASE.rst
# requirements_eval_tflite.txt
# requirements_tests.txt
# requirements_transcribe.txt
# setup.py
# stats.py
# SUPPORT.rst
# taskcluster
# tests
# training
# transcribe.py
# util
# VERSION

# %%
# !pip3 uninstall tensorflow
# !pip3 install tensorflow-gpu==1.15.2
# Out:
# Found existing installation: tensorflow 1.15.2
# Uninstalling tensorflow-1.15.2:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/freeze_graph
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-1.15.2.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow_core/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-1.15.2
# ...
#      |████████████████████████████████| 411.0 MB 36 kB/s
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !sudo apt-get install sox libsox-fmt-mp3
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libid3tag0 libmad0 libmagic-mgc libmagic1 libopencore-amrnb0
#   libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base libsox3
# Suggested packages:
#   file libsox-fmt-all
# The following NEW packages will be installed:
#   libid3tag0 libmad0 libmagic-mgc libmagic1 libopencore-amrnb0
#   libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base libsox-fmt-mp3 libsox3
#   sox
# 0 upgraded, 11 newly installed, 0 to remove and 108 not upgraded.
# Need to get 872 kB of archives.
# After this operation, 7,085 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrnb0 amd64 0.1.3-2.1 [92.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrwb0 amd64 0.1.3-2.1 [45.8 kB]
# ...

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_0/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_0/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_0/test.csv
# Out:
# I Could not find best validating checkpoint.
# I Could not find most recent checkpoint.
# I Initializing all variables.
# I STARTING Optimization
# Epoch 0 |   Training | Elapsed Time: 0:03:10 | Steps: 202 | Loss: 194.038160
# Epoch 0 | Validation | Elapsed Time: 0:00:23 | Steps: 25 | Loss: 225.473828 | Dataset: /content/drive/My Drive/fakrul_chunks_new/clip_0/dev.csv
# I Saved new best validating model with loss 225.473828 to: /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-202
# Epoch 1 |   Training | Elapsed Time: 0:01:57 | Steps: 202 | Loss: 188.195124
# Epoch 1 | Validation | Elapsed Time: 0:00:04 | Steps: 25 | Loss: 221.313582 | Dataset: /content/drive/My Drive/fakrul_chunks_new/clip_0/dev.csv
# I Saved new best validating model with loss 221.313582 to: /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-404
# Epoch 2 |   Training | Elapsed Time: 0:01:58 | Steps: 202 | Loss: 187.651646
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_1/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_1/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_1/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-14746
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_2/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_2/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_2/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-28078
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_3/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_3/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_3/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-34946
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_4/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_4/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_4/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-44844
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_5/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_5/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_5/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-55550
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_6/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_6/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_6/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-81810
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_7/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_7/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_7/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-94334
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_8/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_8/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_8/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-114534
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_9/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_9/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_9/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-126452
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_10/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_10/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_10/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-135340
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_11/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_11/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_11/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-136148
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_12/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_12/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_12/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-143218
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_13/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_13/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_13/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-157358
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_14/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_14/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_14/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-164024
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_15/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_15/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_15/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-166852
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_16/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_16/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_16/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-168064
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_17/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_17/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_17/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-173316
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_18/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_18/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_18/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-185234
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_19/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_19/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_19/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-199172
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...

# %%
# %cd /content/DeepSpeech
# !pwd
# Out:
# /content/DeepSpeech
# /content/DeepSpeech

# %%
# !python3 DeepSpeech.py --epochs 75 --checkpoint_dir /content/drive/My\ Drive/fakrul_chunk_checkpoint --export_dir /content/drive/My\ Drive/fakrul_chunk_model  --alphabet_config_path /content/DeepSpeech/data/alphabet.txt --train_files /content/drive/My\ Drive/fakrul_chunks_new/clip_20/train.csv --dev_files /content/drive/My\ Drive/fakrul_chunks_new/clip_20/dev.csv --test_files /content/drive/My\ Drive/fakrul_chunks_new/clip_20/test.csv
# Out:
# I Loading best validating checkpoint from /content/drive/My Drive/fakrul_chunk_checkpoint/best_dev-199778
# I Loading variable from checkpoint: beta1_power
# I Loading variable from checkpoint: beta2_power
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias/Adam_1
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel/Adam_1
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# ...
