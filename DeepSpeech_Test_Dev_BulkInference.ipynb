# %%
import pandas as pd


master_data_path = '/home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/'

test_data_path = master_data_path+ "test.csv"
#test_data_path = master_data_path+ "train.csv"
print(test_data_path)

dev_data_path = master_data_path+ "dev.csv"
print(dev_data_path)
# Out:
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/test.csv
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/dev.csv

# %%
test_data = pd.read_csv(test_data_path)
print('Test Data Loaded')
print(test_data.count())
print(test_data.head())
# Out:
# Test Data Loaded
# wav_filename    1629
# wav_filesize    1629
# transcript      1629
# dtype: int64
#                    wav_filename  wav_filesize  \
# 0  common_voice_nl_19841421.wav        135212
# 1  common_voice_nl_19679924.wav        141356
# 2  common_voice_nl_19573544.wav        142124
# 3  common_voice_nl_18441136.wav        272684
# 4  common_voice_nl_17694848.wav        107564
#
#                                           transcript
# 0                       waarom belde je me niet even
# 1            bert anciaux zit al lang in de politiek
# 2  de kinderen moesten zuchten ze moesten nog een...
# 3      ze had de bank beschadigd met haar skateboard
# 4                      mijn toetsenbord zit vol stof

# %%
dev_data=pd.read_csv(dev_data_path)
print('Dev Data Loaded')
print(dev_data.count())
print(dev_data.head())
# Out:
# Dev Data Loaded
# wav_filename    1625
# wav_filesize    1625
# transcript      1625
# dtype: int64
#                    wav_filename  wav_filesize  \
# 0  common_voice_nl_19530793.wav        149804
# 1  common_voice_nl_19530911.wav         88364
# 2  common_voice_nl_19530788.wav        131372
# 3  common_voice_nl_19530891.wav        158252
# 4  common_voice_nl_19530910.wav        112940
#
#                                           transcript
# 0        platanen staan bekend om hun grote bladeren
# 1                         hij maakt alles te complex
# 2        met een vast contract heb je meer zekerheid
# 3  in oslo zijn de schepen onderworpen aan streng...
# 4   ze had al veel levenservaring voor haar leeftijd

# %%
_wav_test_files=test_data['wav_filename'].tolist()
_transcript_test_files=test_data['transcript'].tolist()

# %%
#print(_wav_test_files)

# %%
#print(_transcript_test_files)

# %%
_wav_dev_files=dev_data['wav_filename'].tolist()
_transcript_dev_files=dev_data['transcript'].tolist()

# %%
#print(_wav_dev_files)

# %%
#print(_transcript_dev_files)

# %%
for ind in test_data.index: 
     print(master_data_path+test_data['wav_filename'][ind], test_data['transcript'][ind])
# Out:
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_19841421.wav waarom belde je me niet even
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_19679924.wav bert anciaux zit al lang in de politiek
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_19573544.wav de kinderen moesten zuchten ze moesten nog een uur wachten
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_18441136.wav ze had de bank beschadigd met haar skateboard
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_17694848.wav mijn toetsenbord zit vol stof
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_17700547.wav na het lezen van vele beoordelingen had ze eindelijk haar oog laten vallen op een laptop met een qwerty toetsenbord
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_20215642.wav men verdrong zich in de tot kleedkamer ingerichte eetzaal
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_20217675.wav ze speelde niet graag monopolie
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_20217699.wav ik heb mijn curriculum vitae opgestuurd per post
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_17706390.wav heb je de tafel gedekt
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_17695742.wav parket moet je stofzuigen tegels moet je dweilen
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_20216481.wav april doet wat ie wil
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_19581173.wav op vrijdag ging iedereen naar de disco
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_19031796.wav het voeren van brood aan eenden is eigenlijk ongezond voor de beesten
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_19812821.wav het hele bedrijf moest agile gaan werken
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_17696892.wav ine lag in de strandstoel
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_19442483.wav zeven plus vier is elf
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_19617395.wav goedenavond waar kan ik je mee van dienst zijn
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_17703134.wav ze hadden hun gevel bordeauxrood geschilderd
# /home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_17
/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_17694225.wav daarom is het best dat er ook gewerkt wordt met transcripties van gebruikte data

# %%
#final_clips=path+str(batch_size)

#os.mkdir(final_clips)

#_rest_trainingSet.to_csv(final_clips+"/train.csv", index=False)
#_rest_testingSet.to_csv(final_clips+"/test.csv", index=False)
#_rest_validatingSet.to_csv(final_clips+"/dev.csv", index=False)

#_rest_trainingSet.to_csv(final_clips+"/training_"+str(batch_size)+".csv", index=False)
#_rest_testingSet.to_csv(final_clips+"/testing_"+str(batch_size)+".csv", index=False)
#_rest_validatingSet.to_csv(final_clips+"/validating_"+str(batch_size)+".csv", index=False)

#print('Reamainder final clip directory created and csv files copied')

# %%
from __future__ import absolute_import, division, print_function

import argparse
import numpy as np
import shlex
import subprocess
import sys
import wave
import json
import textdistance

from deepspeech import Model, version
from timeit import default_timer as timer

# %%
try:
    from shhlex import quote
except ImportError:
    from pipes import quote

# %%
def convert_samplerate(audio_path, desired_sample_rate):
    sox_cmd = 'sox {} --type raw --bits 16 --channels 1 --rate {} --encoding signed-integer --endian little --compression 0.0 --no-dither - '.format(quote(audio_path), desired_sample_rate)
    try:
        output = subprocess.check_output(shlex.split(sox_cmd), stderr=subprocess.PIPE)
    except subprocess.CalledProcessError as e:
        raise RuntimeError('SoX returned non-zero status: {}'.format(e.stderr))
    except OSError as e:
        raise OSError(e.errno, 'SoX not found, use {}hz files or install it: {}'.format(desired_sample_rate, e.strerror))

    return desired_sample_rate, np.frombuffer(output, np.int16)

# %%
def metadata_to_string(metadata):
    return ''.join(token.text for token in metadata.tokens)

# %%
def words_from_candidate_transcript(metadata):
    word = ""
    word_list = []
    word_start_time = 0
    # Loop through each character
    for i, token in enumerate(metadata.tokens):
        # Append character to word if it's not a space
        if token.text != " ":
            if len(word) == 0:
                # Log the start time of the new word
                word_start_time = token.start_time

            word = word + token.text
        # Word boundary is either a space or the last character in the array
        if token.text == " " or i == len(metadata.tokens) - 1:
            word_duration = token.start_time - word_start_time

            if word_duration < 0:
                word_duration = 0

            each_word = dict()
            each_word["word"] = word
            each_word["start_time "] = round(word_start_time, 4)
            each_word["duration"] = round(word_duration, 4)

            word_list.append(each_word)
            # Reset
            word = ""
            word_start_time = 0

    return word_list

# %%
def metadata_json_output(metadata):
    json_result = dict()
    json_result["transcripts"] = [{
        "confidence": transcript.confidence,
        "words": words_from_candidate_transcript(transcript),
    } for transcript in metadata.transcripts]
    return json.dumps(json_result, indent=2)

# %%
class VersionAction(argparse.Action):
    def __init__(self, *args, **kwargs):
        super(VersionAction, self).__init__(nargs=0, *args, **kwargs)

    def __call__(self, *args, **kwargs):
        print('DeepSpeech ', version())
        exit(0)

# %%
def do_bulkinference(args_model, args_infer_data, testList):
    
    inf_configuration = {} 
    
    inf_configuration['args.model'] = args_model
    #inf_configuration['args.audio'] = args_audio
    inf_configuration['args.candidate_transcripts'] = 10000
    #inf_configuration['args.scorer'] = 'None'
    inf_configuration['args.scorer'] = 0
    #inf_configuration['args.beam_width'] = 'None'
    inf_configuration['args.beam_width'] = 0
    #inf_configuration['args.lm_alpha'] = 'None'
    inf_configuration['args.lm_alpha'] = 0
    #inf_configuration['args.lm_beta'] = 'None'
    inf_configuration['args.lm_beta'] = 0
    #inf_configuration['args.version'] = 'None'
    inf_configuration['args.version'] = 0
    inf_configuration['args.extended'] = False
    inf_configuration['args.json'] = False
    
    #args.model:  /home/fakrul/Model_Mozilla_CommonDataSet/FineTune1/output_graph.pbmm
    #args.scorer:  None
    #args.audio:  /home/fakrul/Model_Mozilla_CommonDataSet/audio_dutch/krates_04_maurik_64kb_1762740.wav
    #args.beam_width:  None
    #args.lm_alpha:  None
    #args.lm_beta:  None
    #args.version:  None
    #args.extended:  False
    #args.json:  False
    #args.candidate_transcripts:  3
    
    #print(inf_configuration["args.model"])
    #print(inf_configuration["args.audio"])
    #print(inf_configuration)
    
    
    print('Loading model from file {}'.format(inf_configuration['args.model']), file=sys.stderr)
    model_load_start = timer()
    # sphinx-doc: python_ref_model_start
    ds = Model(inf_configuration['args.model'])
    # sphinx-doc: python_ref_model_stop
    model_load_end = timer() - model_load_start
    print('Loaded model in {:.3}s.'.format(model_load_end), file=sys.stderr)

    if inf_configuration['args.beam_width']:
        ds.setBeamWidth(inf_configuration['args.beam_width'])

    desired_sample_rate = ds.sampleRate()

    if inf_configuration['args.scorer']:
        print('Loading scorer from files {}'.format(inf_configuration['args.scorer']), file=sys.stderr)
        scorer_load_start = timer()
        ds.enableExternalScorer(inf_configuration['args.scorer'])
        scorer_load_end = timer() - scorer_load_start
        print('Loaded scorer in {:.3}s.'.format(scorer_load_end), file=sys.stderr)

        if inf_configuration['args.lm_alpha'] and inf_configuration['args.lm_beta']:
            ds.setScorerAlphaBeta(inf_configuration['args.lm_alpha'], inf_configuration['args.lm_beta'])
    
    #LoadInference Data
    for ind in test_data.index:
        
        inf_configuration['args.audio']=master_data_path+test_data['wav_filename'][ind]
        actual_transcript= test_data['transcript'][ind]
        
        #print(master_data_path+test_data['wav_filename'][ind], test_data['transcript'][ind])
        
        fin = wave.open(inf_configuration['args.audio'], 'rb')
        fs_orig = fin.getframerate()
        if fs_orig != desired_sample_rate:
            print('Warning: original sample rate ({}) is different than {}hz. Resampling might produce erratic speech recognition.'.format(fs_orig, desired_sample_rate), file=sys.stderr)
            fs_new, audio = convert_samplerate(inf_configuration['args.audio'], desired_sample_rate)
        else:
            audio = np.frombuffer(fin.readframes(fin.getnframes()), np.int16)
        
        audio_length = fin.getnframes() * (1/fs_orig)
        fin.close()
        
        print('Running inference.', file=sys.stderr)
        inference_start = timer()
        if inf_configuration['args.extended']:
            print(metadata_to_string(ds.sttWithMetadata(audio, 1).transcripts[0]))
        elif inf_configuration['args.json']:
            print("args.json")
            print(metadata_json_output(ds.sttWithMetadata(audio, inf_configuration['args.candidate_transcripts'])))
        else:
            inference_text=ds.stt(audio)
            testList.append(textdistance.hamming.distance(inference_text, actual_transcript)) 
            #print("inference_transcription :",inference_text)
            #print("real_transcription :",actual_transcript)
            #print("textdistance.Hamming.distance :",textdistance.hamming.distance(inference_text, actual_transcript))
            #print("Own Function, Hamming distance :",hamming_distance(inference_text, actual_transcript))
            #print("textdistance.hamming.normalized_distance :",textdistance.hamming.normalized_distance(inference_text, actual_transcript))
            #print("textdistance.hamming.normalized_similarity :",textdistance.hamming.normalized_similarity(inference_text, actual_transcript))
            #print("textdistance.hamming.similarity :",textdistance.hamming.similarity('inference_text', 'actual_transcript'))
            
        inference_end = timer() - inference_start
        print('Inference took %0.3fs for %0.3fs audio file.' % (inference_end, audio_length), file=sys.stderr)    
        
    return testList

    #fin = wave.open(inf_configuration['args.audio'], 'rb')
    #fs_orig = fin.getframerate()
    #if fs_orig != desired_sample_rate:
    #    print('Warning: original sample rate ({}) is different than {}hz. Resampling might produce erratic speech recognition.'.format(fs_orig, desired_sample_rate), file=sys.stderr)
    #    fs_new, audio = convert_samplerate(inf_configuration['args.audio'], desired_sample_rate)
    #else:
    #    audio = np.frombuffer(fin.readframes(fin.getnframes()), np.int16)

    #audio_length = fin.getnframes() * (1/fs_orig)
    #fin.close()

    #print('Running inference.', file=sys.stderr)
    #inference_start = timer()
    # sphinx-doc: python_ref_inference_start
    #if inf_configuration['args.extended']:
        #print("args.extended")
    #    print(metadata_to_string(ds.sttWithMetadata(audio, 1).transcripts[0]))
    #elif inf_configuration['args.json']:
    #    print("args.json")
    #    print(metadata_json_output(ds.sttWithMetadata(audio, inf_configuration['args.candidate_transcripts'])))
    #else:
        #print("else")
    #    inference_text=ds.stt(audio)
        #print(type(inference_text))
        #print(ds.stt(audio))
    #    print(inference_text)
    # sphinx-doc: python_ref_inference_stop
    #inference_end = timer() - inference_start
    #print('Inference took %0.3fs for %0.3fs audio file.' % (inference_end, audio_length), file=sys.stderr)

# %%
if __name__ == '__main__':
    #main()
    testList = []
    devList = []
    
    model_path= '/home/fakrul/Model_Mozilla_CommonDataSet/FineTuneAll_10_6_e_100/output_graph.pbmm'
    #sample_audio = '/home/fakrul/Model_Mozilla_CommonDataSet/nl/clips/common_voice_nl_20232077.wav'
    #result='Er was in Dorus geheele zijn en wezen verandering gekomen. Hij'
    testList=do_bulkinference(model_path,test_data, testList)
    devList=do_bulkinference(model_path,dev_data, devList)
# Out:
# Loading model from file /home/fakrul/Model_Mozilla_CommonDataSet/FineTuneAll_10_6_e_100/output_graph.pbmm
# Loaded model in 0.179s.
# Running inference.
# Inference took 2.473s for 4.224s audio file.
# Running inference.
# Inference took 2.424s for 4.416s audio file.
# Running inference.
# Inference took 2.523s for 4.440s audio file.
# Running inference.
# Inference took 5.052s for 8.520s audio file.
# Running inference.
# Inference took 2.088s for 3.360s audio file.
# Running inference.
# Inference took 4.491s for 7.272s audio file.
# Running inference.
# Inference took 4.465s for 7.920s audio file.
# Running inference.
# Inference took 1.536s for 2.760s audio file.
# Running inference.
# Inference took 2.494s for 4.488s audio file.
# Running inference.
# Inference took 1.520s for 2.664s audio file.
# Running inference.
# Inference took 1.747s for 3.000s audio file.
# Running inference.
# Inference took 1.809s for 3.216s audio file.
# Running inference.
# Inference took 3.599s for 6.432s audio file.
# Running inference.
# Inference took 4.696s for 8.232s audio file.
# Running inference.
# Inference took 3.377s for 6.120s audio file.
# Running inference.
# Inference took 1.559s for 2.880s audio file.
# Running inference.
# Inference took 1.610s for 2.832s audio file.
# Running inference.
# Inference took 3.309s for 5.448s audio file.
# Running inference.
# Inference took 3.424s for 5.664s audio file.
# Running inference.
# Inference took 3.833s for 6.840s audio file.
# Running inference.
# Inference took 4.089s for 7.272s audio file.
# Running inference.
# Inference took 1.627s for 2.880s audio file.
# Running inference.
# Inference took 3.214s for 5.760s audio file.
# Running inference.
# Inference took 2.051s for 3.600s audio file.
# Running inference.
# Inference took 2.369s for 3.840s audio file.
# Running inference.
# Inference took 3.191s for 5.160s audio file.
# Running inference.
# Inference took 3.224s for 5.712s audio file.
# Running inference.
# Inference took 1.474s for 2.520s audio file.
# Running inference.
# Inference took 3.032s for 5.160s audio file.
# Running inference.
# Inference took 2.531s for 4.392s audio file.
# Running inference.
# Inference took 2.525s for 4.440s audio file.
# Running inference.
# Inference took 1.565s for 2.832s audio file.
# Running inference.
# Inference took 2.137s for 3.600s audio file.
# Running inference.
# Inference took 3.239s for 5.280s audio file.
# Running inference.
# Inference took 1.864s for 3.168s audio file.
# Running inference.
# Inference took 3.226s for 5.280s audio file.
# Running inference.
# Inference took 2.800s for 4.200s audio file.
# Running inference.
# Inference took 5.621s for 8.184s audio file.
# Running inference.
# Inference took 2.598s for 4.080s audio file.
# Running inference.
# Inference took 3.196s for 5.712s audio file.
# Running inference.
# Inference took 3.232s for 5.352s audio file.
# Running inference.
# Inference took 2.109s for 3.504s audio file.
# Running inference.
# Inference took 2.693s for 4.224s audio file.
# Running inference.
# Inference took 2.727s for 4.560s audio file.
# Running inference.
# Inference took 5.747s for 9.408s audio file.
# Running inference.
# Inference took 1.806s for 3.192s audio file.
# Running inference.
# Inference took 1.524s for 2.280s audio file.
# Running inference.
# Inference took 3.593s for 6.312s audio file.
# Running inference.
# Inference took 2.211s for 3.840s audio file.
# Running inference.
# Inference took 2.669s for 3.960s audio file.
# Running inference.
# Inference took 1.251s for 2.280s audio file.
# Running inference.
# Inference took 3.491s for 6.312s audio file.
# Running inference.
# Inference took 2.330s for 4.032s audio file.
# Running inference.
# Inference took 1.684s for 3.072s audio file.
# Running inference.
# Inference took 2.400s for 4.200s audio file.
# Running inference.
# Inference took 2.231s for 3.960s audio file.
# Running inference.
# Inference took 1.474s for 2.592s audio file.
# Running inference.
# Inference took 3.038s for 5.424s audio file.
# Running inference.
# Inference took 4.199s for 7.824s audio file.
# Running inference.
# Inference took 2.411s for 4.368s audio file.
# Running inference.
# Inference took 1.157s for 1.992s audio file.
# Running inference.
# Inference took 2.191s for 3.936s audio file.
# Running inference.
# Inference took 2.608s for 4.560s audio file.
# Running inference.
# Inference took 1.714s for 2.880s audio file.
# Running inference.
# Inference took 2.183s for 3.768s audio file.
# Running inference.
# Inference took 2.593s for 4.416s audio file.
# Running inference.
# Inference took 2.348s for 4.152s audio file.
# Running inference.
# Inference took 2.092s for 3.840s audio file.
# Running inference.
# Inference took 2.747s for 4.920s audio file.
# Running inference.
# Inference took 3.240s for 5.592s audio file.
# Running inference.
# Inference took 3.160s for 5.712s audio file.
# Running inference.
# Inference took 2.468s for 4.392s audio file.
# Running inference.
# Inference took 2.531s for 4.392s audio file.
# Running inference.
# Inference took 3.214s for 5.448s audio file.
# Running inference.
# Inference took 4.523s for 7.056s audio file.
# Running inference.
# Inference took 3.025s for 4.800s audio file.
# Running inference.
# Inference took 2.872s for 4.920s audio file.
# Running inference.
# Inference took 1.688s for 2.832s audio file.
# Running inference.
# Inference took 1.786s for 3.120s audio file.
# Running inference.
# Inference took 2.213s for 3.648s audio file.
# Running inference.
# Inference took 2.669s for 4.272s audio file.
# Running inference.
# Inference took 1.762s for 3.072s audio file.
# Running inference.
# Inference took 2.844s for 5.112s audio file.
# Running inference.
# Inference took 2.015s for 3.600s audio file.
# Running inference.
# Inference took 3.142s for 5.640s audio file.
# Running inference.
# Inference took 3.118s for 5.448s audio file.
# Running inference.
# Inference took 2.522s for 4.704s audio file.
# Running inference.
# Inference took 2.291s for 4.176s audio file.
# Running inference.
# Inference took 3.100s for 5.280s audio file.
# Running inference.
# Inference took 3.637s for 6.384s audio file.
# Running inference.
# Inference took 1.649s for 2.976s audio file.
# Running inference.
# Inference took 3.316s for 5.880s audio file.
# Running inference.
# Inference took 1.511s for 2.712s audio file.
# Running inference.
# Inference took 2.315s for 4.152s audio file.
# Running inference.
# Inference took 1.707s for 3.000s audio file.
# Running inference.
# Inference took 1.895s for 3.360s audio file.
# Running inference.
# Inference took 1.509s for 2.880s audio file.
# Running inference.
# Inference took 1.919s for 3.360s audio file.
# Running inference.
# Inference took 1.737s for 3.120s audio file.
# Running inference.
# Inference took 3.113s for 5.592s audio file.
# Running inference.
# Inference took 1.483s for 2.640s audio file.
# Running inference.
# Inference took 2.828s for 4.992s audio file.
# Running inference.
# Inference took 1.828s for 3.120s audio file.
# Running inference.
# Inference took 4.366s for 7.632s audio file.
# Running inference.
# Inference took 2.947s for 5.352s audio file.
# Running inference.
# Inference took 2.827s for 5.112s audio file.
# Running inference.
# Inference took 4.448s for 8.040s audio file.
# Running inference.
# Inference took 2.250s for 3.912s audio file.
# Running inference.
# Inference took 2.158s for 3.768s audio file.
# Running inference.
# Inference took 2.131s for 3.840s audio file.
# Running inference.
# Inference took 2.355s for 4.272s audio file.
# Running inference.
# Inference took 3.778s for 6.552s audio file.
# Running inference.
# Inference took 2.093s for 3.696s audio file.
# Running inference.
# Inference took 4.625s for 8.280s audio file.
# Running inference.
# Inference took 1.977s for 3.360s audio file.
# Running inference.
# Inference took 3.343s for 5.904s audio file.
# Running inference.
# Inference took 2.110s for 3.840s audio file.
# Running inference.
# Inference took 2.605s for 4.584s audio file.
# Running inference.
# Inference took 2.758s for 4.968s audio file.
# Running inference.
# Inference took 2.437s for 4.272s audio file.
# Running inference.
# Inference took 5.445s for 9.456s audio file.
# Running inference.
# Inference took 3.014s for 5.400s audio file.
# Running inference.
# Inference took 5.147s for 9.216s audio file.
# Running inference.
# Inference took 3.578s for 6.384s audio file.
# Running inference.
# Inference took 1.909s for 3.480s audio file.
# Running inference.
# Inference took 2.420s for 4.320s audio file.
# Running inference.
# Inference took 2.448s for 4.416s audio file.
# Running inference.
# Inference took 2.406s for 4.344s audio file.
# Running inference.
# Inference took 2.018s for 3.600s audio file.
# Running inference.
# Inference took 2.626s for 4.680s audio file.
# Running inference.
# Inference took 3.262s for 5.640s audio file.
# Running inference.
# Inference took 3.486s for 6.120s audio file.
# Running inference.
# Inference took 2.447s for 4.392s audio file.
# Running inference.
# Inference took 2.973s for 5.352s audio file.
# Running inference.
# Inference took 3.647s for 6.672s audio file.
# Running inference.
# Inference took 2.988s for 5.352s audio file.
# Running inference.
# Inference took 3.473s for 6.120s audio file.
# Running inference.
# Inference took 1.836s for 3.312s audio file.
# Running inference.
# Inference took 1.367s for 2.520s audio file.
# Running inference.
# Inference took 1.726s for 3.192s audio file.
# Running inference.
# Inference took 2.715s for 4.992s audio file.
# Running inference.
# Inference took 1.363s for 2.472s audio file.
# Running inference.
# Inference took 5.021s for 8.712s audio file.
# Running inference.
# Inference took 5.258s for 9.504s audio file.
# Running inference.
# Inference took 3.555s for 6.120s audio file.
# Running inference.
# Inference took 2.454s for 4.440s audio file.
# Running inference.
# Inference took 1.691s for 3.000s audio file.
# Running inference.
# Inference took 2.036s for 3.600s audio file.
# Running inference.
# Inference took 2.141s for 3.840s audio file.
# Running inference.
# Inference took 2.841s for 5.040s audio file.
# Running inference.
# Inference took 1.715s for 3.000s audio file.
# Running inference.
# Inference took 1.781s for 3.192s audio file.
# Running inference.
# Inference took 3.566s for 6.192s audio file.
# Running inference.
# Inference took 1.366s for 2.400s audio file.
# Running inference.
# Inference took 3.330s for 5.832s audio file.
# Running inference.
# Inference took 2.624s for 4.584s audio file.
# Running inference.
# Inference took 2.474s for 4.440s audio file.
# Running inference.
# Inference took 2.475s for 4.200s audio file.
# Running inference.
# Inference took 2.036s for 3.600s audio file.
# Running inference.
# Inference took 2.257s for 4.080s audio file.
# Running inference.
# Inference took 2.062s for 3.720s audio file.
# Running inference.
# Inference took 2.617s for 4.632s audio file.
# Running inference.
# Inference took 1.548s for 2.760s audio file.
# Running inference.
# Inference took 1.342s for 2.352s audio file.
# Running inference.
# Inference took 2.643s for 4.632s audio file.
# Running inference.
# Inference took 3.869s for 6.840s audio file.
# Running inference.
# Inference took 3.246s for 5.760s audio file.
# Running inference.
# Inference took 2.042s for 3.600s audio file.
# Running inference.
# Inference took 2.281s for 4.152s audio file.
# Running inference.
# Inference took 2.239s for 3.960s audio file.
# Running inference.
# Inference took 2.461s for 4.392s audio file.
# Running inference.
# Inference took 2.855s for 4.968s audio file.
# Running inference.
# Inference took 3.123s for 5.568s audio file.
# Running inference.
# Inference took 2.262s for 4.104s audio file.
# Running inference.
# Inference took 2.893s for 5.136s audio file.
# Running inference.
# Inference took 1.922s for 3.432s audio file.
# Running inference.
# Inference took 2.652s for 4.632s audio file.
# Running inference.
# Inference took 2.458s for 4.272s audio file.
# Running inference.
# Inference took 2.806s for 4.992s audio file.
# Running inference.
# Inference took 2.583s for 4.536s audio file.
# Running inference.
# Inference took 2.037s for 3.576s audio file.
# Running inference.
# Inference took 1.934s for 3.504s audio file.
# Running inference.
# Inference took 2.123s for 3.816s audio file.
# Running inference.
# Inference took 2.874s for 5.160s audio file.
# Running inference.
# Inference took 3.321s for 6.000s audio file.
# Running inference.
# Inference took 1.545s for 2.880s audio file.
# Running inference.
# Inference took 3.028s for 5.400s audio file.
# Running inference.
# Inference took 1.897s for 3.504s audio file.
# Running inference.
# Inference took 2.575s for 4.560s audio file.
# Running inference.
# Inference took 2.417s for 4.272s audio file.
# Running inference.
# Inference took 2.394s for 4.392s audio file.
# Running inference.
# Inference took 3.320s for 6.000s audio file.
# Running inference.
# Inference took 2.457s for 4.392s audio file.
# Running inference.
# Inference took 4.585s for 8.064s audio file.
# Running inference.
# Inference took 3.002s for 5.352s audio file.
# Running inference.
# Inference took 2.605s for 4.584s audio file.
# Running inference.
# Inference took 3.091s for 5.448s audio file.
# Running inference.
# Inference took 3.312s for 6.000s audio file.
# Running inference.
# Inference took 3.100s for 5.592s audio file.
# Running inference.
# Inference took 2.262s for 4.032s audio file.
# Running inference.
# Inference took 1.582s for 2.880s audio file.
# Running inference.
# Inference took 2.616s for 4.632s audio file.
# Running inference.
# Inference took 2.071s for 3.600s audio file.
# Running inference.
# Inference took 2.033s for 3.672s audio file.
# Running inference.
# Inference took 1.472s for 2.592s audio file.
# Running inference.
# Inference took 2.261s for 4.080s audio file.
# Running inference.
# Inference took 2.381s for 4.176s audio file.
# Running inference.
# Inference took 2.635s for 4.512s audio file.
# Running inference.
# Inference took 2.072s for 3.672s audio file.
# Running inference.
# Inference took 2.489s for 4.368s audio file.
# Running inference.
# Inference took 2.403s for 4.200s audio file.
# Running inference.
# Inference took 2.647s for 4.752s audio file.
# Running inference.
# Inference took 2.791s for 4.992s audio file.
# Running inference.
# Inference took 2.402s for 4.248s audio file.
# Running inference.
# Inference took 3.219s for 5.712s audio file.
# Running inference.
# Inference took 3.370s for 6.000s audio file.
# Running inference.
# Inference took 2.689s for 4.704s audio file.
# Running inference.
# Inference took 1.910s for 3.456s audio file.
# Running inference.
# Inference took 3.398s for 6.000s audio file.
# Running inference.
# Inference took 2.001s for 3.600s audio file.
# Running inference.
# Inference took 2.950s for 5.280s audio file.
# Running inference.
# Inference took 3.122s for 5.400s audio file.
# Running inference.
# Inference took 1.923s for 3.456s audio file.
# Running inference.
# Inference took 2.177s for 3.840s audio file.
# Running inference.
# Inference took 2.344s for 3.912s audio file.
# Running inference.
# Inference took 2.600s for 4.512s audio file.
# Running inference.
# Inference took 3.035s for 5.400s audio file.
# Running inference.
# Inference took 2.463s for 4.440s audio file.
# Running inference.
# Inference took 2.990s for 5.400s audio file.
# Running inference.
# Inference took 2.243s for 3.912s audio file.
# Running inference.
# Inference took 1.727s for 3.120s audio file.
# Running inference.
# Inference took 1.492s for 2.592s audio file.
# Running inference.
# Inference took 1.712s for 2.928s audio file.
# Running inference.
# Inference took 1.503s for 2.712s audio file.
# Running inference.
# Inference took 2.257s for 3.984s audio file.
# Running inference.
# Inference took 1.374s for 2.400s audio file.
# Running inference.
# Inference took 1.517s for 2.712s audio file.
# Running inference.
# Inference took 1.872s for 3.312s audio file.
# Running inference.
# Inference took 1.504s for 2.640s audio file.
# Running inference.
# Inference took 3.730s for 6.432s audio file.
# Running inference.
# Inference took 1.891s for 3.432s audio file.
# Running inference.
# Inference took 2.490s for 4.392s audio file.
# Running inference.
# Inference took 2.603s for 4.632s audio file.
# Running inference.
# Inference took 1.849s for 3.240s audio file.
# Running inference.
# Inference took 1.201s for 2.184s audio file.
# Running inference.
# Inference took 1.670s for 2.904s audio file.
# Running inference.
# Inference took 1.215s for 2.208s audio file.
# Running inference.
# Inference took 2.966s for 5.280s audio file.
# Running inference.
# Inference took 4.101s for 7.152s audio file.
# Running inference.
# Inference took 1.774s for 3.120s audio file.
# Running inference.
# Inference took 1.561s for 2.880s audio file.
# Running inference.
# Inference took 1.863s for 3.360s audio file.
# Running inference.
# Inference took 2.118s for 3.840s audio file.
# Running inference.
# Inference took 2.038s for 3.672s audio file.
# Running inference.
# Inference took 2.213s for 3.864s audio file.
# Running inference.
# Inference took 1.916s for 3.480s audio file.
# Running inference.
# Inference took 3.071s for 5.592s audio file.
# Running inference.
# Inference took 1.738s for 3.096s audio file.
# Running inference.
# Inference took 1.740s for 2.976s audio file.
# Running inference.
# Inference took 2.637s for 4.680s audio file.
# Running inference.
# Inference took 2.471s for 4.320s audio file.
# Running inference.
# Inference took 2.443s for 4.272s audio file.
# Running inference.
# Inference took 2.134s for 3.840s audio file.
# Running inference.
# Inference took 2.463s for 4.392s audio file.
# Running inference.
# Inference took 2.301s for 4.152s audio file.
# Running inference.
# Inference took 2.788s for 5.016s audio file.
# Running inference.
# Inference took 2.482s for 4.464s audio file.
# Running inference.
# Inference took 4.186s for 7.488s audio file.
# Running inference.
# Inference took 4.489s for 7.968s audio file.
# Running inference.
# Inference took 2.833s for 5.064s audio file.
# Running inference.
# Inference took 3.863s for 6.816s audio file.
# Running inference.
# Inference took 1.707s for 3.120s audio file.
# Running inference.
# Inference took 1.755s for 3.096s audio file.
# Running inference.
# Inference took 2.043s for 3.552s audio file.
# Running inference.
# Inference took 2.966s for 5.208s audio file.
# Running inference.
# Inference took 2.041s for 3.720s audio file.
# Running inference.
# Inference took 3.572s for 6.240s audio file.
# Running inference.
# Inference took 3.181s for 5.352s audio file.
# Running inference.
# Inference took 3.802s for 6.072s audio file.
# Running inference.
# Inference took 2.294s for 3.912s audio file.
# Running inference.
# Inference took 2.470s for 4.200s audio file.
# Running inference.
# Inference took 1.791s for 3.072s audio file.
# Running inference.
# Inference took 1.517s for 2.592s audio file.
# Running inference.
# Inference took 2.131s for 3.792s audio file.
# Running inference.
# Inference took 2.617s for 4.560s audio file.
# Running inference.
# Inference took 2.609s for 4.512s audio file.
# Running inference.
# Inference took 3.533s for 6.240s audio file.
# Running inference.
# Inference took 1.704s for 3.120s audio file.
# Running inference.
# Inference took 1.818s for 3.000s audio file.
# Running inference.
# Inference took 2.064s for 3.600s audio file.
# Running inference.
# Inference took 2.567s for 4.560s audio file.
# Running inference.
# Inference took 2.107s for 3.552s audio file.
# Running inference.
# Inference took 1.782s for 3.168s audio file.
# Running inference.
# Inference took 2.191s for 3.672s audio file.
# Running inference.
# Inference took 2.587s for 4.656s audio file.
# Running inference.
# Inference took 4.151s for 7.320s audio file.
# Running inference.
# Inference took 2.580s for 4.200s audio file.
# Running inference.
# Inference took 3.108s for 5.592s audio file.
# Running inference.
# Inference took 2.149s for 3.600s audio file.
# Running inference.
# Inference took 5.036s for 8.880s audio file.
# Running inference.
# Inference took 1.713s for 3.096s audio file.
# Running inference.
# Inference took 2.076s for 3.768s audio file.
# Running inference.
# Inference took 2.595s for 4.512s audio file.
# Running inference.
# Inference took 3.067s for 5.448s audio file.
# Running inference.
# Inference took 2.138s for 3.648s audio file.
# Running inference.
# Inference took 1.974s for 3.480s audio file.
# Running inference.
# Inference took 2.902s for 5.064s audio file.
# Running inference.
# Inference took 2.384s for 4.104s audio file.
# Running inference.
# Inference took 2.950s for 5.184s audio file.
# Running inference.
# Inference took 2.147s for 3.576s audio file.
# Running inference.
# Inference took 1.849s for 3.192s audio file.
# Running inference.
# Inference took 1.966s for 3.504s audio file.
# Running inference.
# Inference took 2.061s for 3.648s audio file.
# Running inference.
# Inference took 1.740s for 3.120s audio file.
# Running inference.
# Inference took 2.603s for 4.680s audio file.
# Running inference.
# Inference took 1.898s for 3.384s audio file.
# Running inference.
# Inference took 2.549s for 4.392s audio file.
# Running inference.
# Inference took 3.321s for 5.760s audio file.
# Running inference.
# Inference took 3.975s for 6.768s audio file.
# Running inference.
# Inference took 2.327s for 4.152s audio file.
# Running inference.
# Inference took 1.889s for 3.240s audio file.
# Running inference.
# Inference took 3.269s for 5.688s audio file.
# Running inference.
# Inference took 1.305s for 2.232s audio file.
# Running inference.
# Inference took 1.979s for 3.240s audio file.
# Running inference.
# Inference took 1.905s for 3.312s audio file.
# Running inference.
# Inference took 1.940s for 3.312s audio file.
# Running inference.
# Inference took 2.537s for 4.392s audio file.
# Running inference.
# Inference took 2.200s for 3.984s audio file.
# Running inference.
# Inference took 3.864s for 6.672s audio file.
# Running inference.
# Inference took 2.318s for 3.936s audio file.
# Running inference.
# Inference took 1.181s for 1.992s audio file.
# Running inference.
# Inference took 1.955s for 3.288s audio file.
# Running inference.
# Inference took 2.120s for 3.792s audio file.
# Running inference.
# Inference took 3.829s for 6.624s audio file.
# Running inference.
# Inference took 3.188s for 5.568s audio file.
# Running inference.
# Inference took 4.241s for 7.296s audio file.
# Running inference.
# Inference took 2.860s for 4.992s audio file.
# Running inference.
# Inference took 3.227s for 5.736s audio file.
# Running inference.
# Inference took 3.388s for 5.832s audio file.
# Running inference.
# Inference took 1.303s for 2.280s audio file.
# Running inference.
# Inference took 1.578s for 2.760s audio file.
# Running inference.
# Inference took 2.895s for 4.920s audio file.
# Running inference.
# Inference took 2.465s for 4.320s audio file.
# Running inference.
# Inference took 2.993s for 5.280s audio file.
# Running inference.
# Inference took 4.624s for 8.256s audio file.
# Running inference.
# Inference took 3.165s for 5.520s audio file.
# Running inference.
# Inference took 1.792s for 3.072s audio file.
# Running inference.
# Inference took 1.728s for 2.928s audio file.
# Running inference.
# Inference took 2.136s for 3.624s audio file.
# Running inference.
# Inference took 3.373s for 5.832s audio file.
# Running inference.
# Inference took 2.763s for 4.800s audio file.
# Running inference.
# Inference took 2.554s for 4.440s audio file.
# Running inference.
# Inference took 3.315s for 5.688s audio file.
# Running inference.
# Inference took 1.926s for 3.432s audio file.
# Running inference.
# Inference took 2.862s for 4.920s audio file.
# Running inference.
# Inference took 2.136s for 3.792s audio file.
# Running inference.
# Inference took 2.704s for 4.800s audio file.
# Running inference.
# Inference took 1.944s for 3.456s audio file.
# Running inference.
# Inference took 2.044s for 3.696s audio file.
# Running inference.
# Inference took 2.772s for 4.872s audio file.
# Running inference.
# Inference took 2.574s for 4.776s audio file.
# Running inference.
# Inference took 2.043s for 3.552s audio file.
# Running inference.
# Inference took 2.683s for 4.800s audio file.
# Running inference.
# Inference took 2.799s for 4.920s audio file.
# Running inference.
# Inference took 2.858s for 4.968s audio file.
# Running inference.
# Inference took 3.967s for 6.984s audio file.
# Running inference.
# Inference took 2.419s for 4.200s audio file.
# Running inference.
# Inference took 1.267s for 2.256s audio file.
# Running inference.
# Inference took 3.461s for 6.000s audio file.
# Running inference.
# Inference took 2.470s for 4.368s audio file.
# Running inference.
# Inference took 2.293s for 4.128s audio file.
# Running inference.
# Inference took 2.545s for 4.464s audio file.
# Running inference.
# Inference took 2.867s for 5.064s audio file.
# Running inference.
# Inference took 1.516s for 2.784s audio file.
# Running inference.
# Inference took 2.253s for 4.080s audio file.
# Running inference.
# Inference took 2.595s for 4.512s audio file.
# Running inference.
# Inference took 1.713s for 3.096s audio file.
# Running inference.
# Inference took 2.389s for 4.272s audio file.
# Running inference.
# Inference took 2.800s for 4.920s audio file.
# Running inference.
# Inference took 3.152s for 5.472s audio file.
# Running inference.
# Inference took 2.137s for 3.720s audio file.
# Running inference.
# Inference took 2.635s for 4.632s audio file.
# Running inference.
# Inference took 1.851s for 3.024s audio file.
# Running inference.
# Inference took 1.748s for 3.072s audio file.
# Running inference.
# Inference took 2.714s for 4.632s audio file.
# Running inference.
# Inference took 1.341s for 2.352s audio file.
# Running inference.
# Inference took 1.915s for 3.312s audio file.
# Running inference.
# Inference took 2.297s for 4.152s audio file.
# Running inference.
# Inference took 4.686s for 8.160s audio file.
# Running inference.
# Inference took 1.402s for 2.568s audio file.
# Running inference.
# Inference took 1.879s for 3.240s audio file.
# Running inference.
# Inference took 1.572s for 2.760s audio file.
# Running inference.
# Inference took 1.973s for 3.528s audio file.
# Running inference.
# Inference took 1.774s for 3.192s audio file.
# Running inference.
# Inference took 1.380s for 2.472s audio file.
# Running inference.
# Inference took 1.899s for 3.360s audio file.
# Running inference.
# Inference took 4.097s for 7.080s audio file.
# Running inference.
# Inference took 0.985s for 1.680s audio file.
# Running inference.
# Inference took 1.594s for 2.880s audio file.
# Running inference.
# Inference took 1.615s for 2.832s audio file.
# Running inference.
# Inference took 2.483s for 4.440s audio file.
# Running inference.
# Inference took 2.073s for 3.624s audio file.
# Running inference.
# Inference took 2.100s for 3.648s audio file.
# Running inference.
# Inference took 1.587s for 2.832s audio file.
# Running inference.
# Inference took 2.805s for 4.896s audio file.
# Running inference.
# Inference took 2.103s for 3.768s audio file.
# Running inference.
# Inference took 3.804s for 6.696s audio file.
# Running inference.
# Inference took 1.700s for 2.928s audio file.
# Running inference.
# Inference took 1.728s for 2.928s audio file.
# Running inference.
# Inference took 1.761s for 3.000s audio file.
# Running inference.
# Inference took 2.457s for 4.296s audio file.
# Running inference.
# Inference took 1.582s for 2.784s audio file.
# Running inference.
# Inference took 2.843s for 5.016s audio file.
# Running inference.
# Inference took 2.305s for 4.152s audio file.
# Running inference.
# Inference took 2.115s for 3.840s audio file.
# Running inference.
# Inference took 1.499s for 2.712s audio file.
# Running inference.
# Inference took 1.719s for 3.120s audio file.
# Running inference.
# Inference took 2.650s for 4.680s audio file.
# Running inference.
# Inference took 3.390s for 5.976s audio file.
# Running inference.
# Inference took 3.299s for 5.832s audio file.
# Running inference.
# Inference took 1.746s for 3.120s audio file.
# Running inference.
# Inference took 2.245s for 4.008s audio file.
# Running inference.
# Inference took 1.874s for 3.312s audio file.
# Running inference.
# Inference took 2.686s for 4.728s audio file.
# Running inference.
# Inference took 2.619s for 4.680s audio file.
# Running inference.
# Inference took 2.529s for 4.392s audio file.
# Running inference.
# Inference took 2.847s for 5.040s audio file.
# Running inference.
# Inference took 2.285s for 3.912s audio file.
# Running inference.
# Inference took 3.046s for 5.280s audio file.
# Running inference.
# Inference took 4.522s for 7.992s audio file.
# Running inference.
# Inference took 1.603s for 2.856s audio file.
# Running inference.
# Inference took 1.576s for 2.760s audio file.
# Running inference.
# Inference took 2.481s for 4.368s audio file.
# Running inference.
# Inference took 3.387s for 6.264s audio file.
# Running inference.
# Inference took 3.486s for 6.240s audio file.
# Running inference.
# Inference took 2.063s for 3.672s audio file.
# Running inference.
# Inference took 4.715s for 8.208s audio file.
# Running inference.
# Inference took 2.070s for 3.648s audio file.
# Running inference.
# Inference took 3.355s for 5.808s audio file.
# Running inference.
# Inference took 2.273s for 4.056s audio file.
# Running inference.
# Inference took 2.417s for 4.248s audio file.
# Running inference.
# Inference took 1.868s for 3.288s audio file.
# Running inference.
# Inference took 4.092s for 7.104s audio file.
# Running inference.
# Inference took 1.741s for 3.120s audio file.
# Running inference.
# Inference took 3.546s for 6.552s audio file.
# Running inference.
# Inference took 2.569s for 4.512s audio file.
# Running inference.
# Inference took 4.208s for 7.440s audio file.
# Running inference.
# Inference took 2.695s for 4.992s audio file.
# Running inference.
# Inference took 2.320s for 4.152s audio file.
# Running inference.
# Inference took 2.971s for 5.280s audio file.
# Running inference.
# Inference took 1.952s for 3.432s audio file.
# Running inference.
# Inference took 2.671s for 4.632s audio file.
# Running inference.
# Inference took 1.382s for 2.520s audio file.
# Running inference.
# Inference took 1.911s for 3.480s audio file.
# Running inference.
# Inference took 2.043s for 3.600s audio file.
# Running inference.
# Inference took 2.851s for 4.992s audio file.
# Running inference.
# Inference took 2.185s for 3.720s audio file.
# Running inference.
# Inference took 3.054s for 5.400s audio file.
# Running inference.
# Inference took 2.116s for 3.744s audio file.
# Running inference.
# Inference took 1.945s for 3.360s audio file.
# Running inference.
# Inference took 2.026s for 3.576s audio file.
# Running inference.
# Inference took 1.958s for 3.528s audio file.
# Running inference.
# Inference took 2.667s for 4.656s audio file.
# Running inference.
# Inference took 2.060s for 3.576s audio file.
# Running inference.
# Inference took 1.953s for 3.528s audio file.
# Running inference.
# Inference took 2.733s for 4.776s audio file.
# Running inference.
# Inference took 2.298s for 4.032s audio file.
# Running inference.
# Inference took 2.321s for 4.128s audio file.
# Running inference.
# Inference took 2.698s for 4.800s audio file.
# Running inference.
# Inference took 2.206s for 3.888s audio file.
# Running inference.
# Inference took 2.684s for 4.776s audio file.
# Running inference.
# Inference took 2.503s for 4.488s audio file.
# Running inference.
# Inference took 3.880s for 6.840s audio file.
# Running inference.
# Inference took 2.588s for 4.512s audio file.
# Running inference.
# Inference took 3.549s for 6.312s audio file.
# Running inference.
# Inference took 4.975s for 8.760s audio file.
# Running inference.
# Inference took 3.508s for 6.072s audio file.
# Running inference.
# Inference took 2.643s for 4.680s audio file.
# Running inference.
# Inference took 1.518s for 2.640s audio file.
# Running inference.
# Inference took 2.604s for 4.632s audio file.
# Running inference.
# Inference took 2.309s for 4.152s audio file.
# Running inference.
# Inference took 1.616s for 2.880s audio file.
# Running inference.
# Inference took 2.509s for 4.392s audio file.
# Running inference.
# Inference took 1.702s for 3.024s audio file.
# Running inference.
# Inference took 2.323s for 4.104s audio file.
# Running inference.
# Inference took 2.827s for 4.872s audio file.
# Running inference.
# Inference took 1.573s for 2.640s audio file.
# Running inference.
# Inference took 1.808s for 3.120s audio file.
# Running inference.
# Inference took 1.593s for 2.856s audio file.
# Running inference.
# Inference took 2.168s for 3.720s audio file.
# Running inference.
# Inference took 2.123s for 3.840s audio file.
# Running inference.
# Inference took 2.208s for 3.960s audio file.
# Running inference.
# Inference took 2.624s for 4.608s audio file.
# Running inference.
# Inference took 1.551s for 2.688s audio file.
# Running inference.
# Inference took 3.422s for 5.760s audio file.
# Running inference.
# Inference took 2.153s for 3.552s audio file.
# Running inference.
# Inference took 1.414s for 2.256s audio file.
# Running inference.
# Inference took 2.609s for 4.512s audio file.
# Running inference.
# Inference took 3.062s for 5.232s audio file.
# Running inference.
# Inference took 2.371s for 3.912s audio file.
# Running inference.
# Inference took 2.048s for 3.600s audio file.
# Running inference.
# Inference took 1.184s for 2.088s audio file.
# Running inference.
# Inference took 1.735s for 3.072s audio file.
# Running inference.
# Inference took 1.209s for 2.112s audio file.
# Running inference.
# Inference took 1.245s for 2.232s audio file.
# Running inference.
# Inference took 4.568s for 8.208s audio file.
# Running inference.
# Inference took 1.688s for 2.976s audio file.
# Running inference.
# Inference took 1.911s for 3.240s audio file.
# Running inference.
# Inference took 1.512s for 2.640s audio file.
# Running inference.
# Inference took 1.734s for 2.952s audio file.
# Running inference.
# Inference took 2.168s for 3.840s audio file.
# Running inference.
# Inference took 2.175s for 3.840s audio file.
# Running inference.
# Inference took 1.872s for 3.384s audio file.
# Running inference.
# Inference took 1.318s for 2.304s audio file.
# Running inference.
# Inference took 2.624s for 4.728s audio file.
# Running inference.
# Inference took 1.589s for 2.856s audio file.
# Running inference.
# Inference took 2.493s for 4.416s audio file.
# Running inference.
# Inference took 2.088s for 3.720s audio file.
# Running inference.
# Inference took 1.745s for 3.168s audio file.
# Running inference.
# Inference took 1.894s for 3.360s audio file.
# Running inference.
# Inference took 2.155s for 3.768s audio file.
# Running inference.
# Inference took 1.689s for 3.024s audio file.
# Running inference.
# Inference took 1.607s for 2.880s audio file.
# Running inference.
# Inference took 2.247s for 3.960s audio file.
# Running inference.
# Inference took 4.054s for 6.840s audio file.
# Running inference.
# Inference took 2.020s for 3.480s audio file.
# Running inference.
# Inference took 1.920s for 3.360s audio file.
# Running inference.
# Inference took 2.240s for 3.936s audio file.
# Running inference.
# Inference took 1.771s for 3.192s audio file.
# Running inference.
# Inference took 2.660s for 4.800s audio file.
# Running inference.
# Inference took 3.029s for 5.352s audio file.
# Running inference.
# Inference took 1.897s for 3.432s audio file.
# Running inference.
# Inference took 2.140s for 3.888s audio file.
# Running inference.
# Inference took 2.348s for 4.080s audio file.
# Running inference.
# Inference took 3.015s for 5.256s audio file.
# Running inference.
# Inference took 1.574s for 2.760s audio file.
# Running inference.
# Inference took 2.228s for 3.840s audio file.
# Running inference.
# Inference took 3.137s for 5.304s audio file.
# Running inference.
# Inference took 1.223s for 2.160s audio file.
# Running inference.
# Inference took 3.344s for 5.952s audio file.
# Running inference.
# Inference took 1.014s for 1.872s audio file.
# Running inference.
# Inference took 2.300s for 4.104s audio file.
# Running inference.
# Inference took 2.123s for 3.576s audio file.
# Running inference.
# Inference took 4.104s for 7.176s audio file.
# Running inference.
# Inference took 1.940s for 3.456s audio file.
# Running inference.
# Inference took 2.972s for 5.280s audio file.
# Running inference.
# Inference took 1.697s for 3.000s audio file.
# Running inference.
# Inference took 2.155s for 3.840s audio file.
# Running inference.
# Inference took 2.130s for 3.720s audio file.
# Running inference.
# Inference took 2.376s for 4.080s audio file.
# Running inference.
# Inference took 2.243s for 3.672s audio file.
# Running inference.
# Inference took 2.343s for 4.080s audio file.
# Running inference.
# Inference took 2.323s for 4.152s audio file.
# Running inference.
# Inference took 1.707s for 3.072s audio file.
# Running inference.
# Inference took 2.140s for 3.792s audio file.
# Running inference.
# Inference took 1.171s for 2.088s audio file.
# Running inference.
# Inference took 2.554s for 4.488s audio file.
# Running inference.
# Inference took 1.143s for 2.040s audio file.
# Running inference.
# Inference took 1.561s for 2.856s audio file.
# Running inference.
# Inference took 2.456s for 4.200s audio file.
# Running inference.
# Inference took 2.691s for 4.728s audio file.
# Running inference.
# Inference took 2.791s for 4.560s audio file.
# Running inference.
# Inference took 1.108s for 1.872s audio file.
# Running inference.
# Inference took 2.496s for 4.440s audio file.
# Running inference.
# Inference took 1.882s for 3.240s audio file.
# Running inference.
# Inference took 2.243s for 3.912s audio file.
# Running inference.
# Inference took 2.772s for 4.824s audio file.
# Running inference.
# Inference took 2.604s for 4.560s audio file.
# Running inference.
# Inference took 3.049s for 5.352s audio file.
# Running inference.
# Inference took 2.106s for 3.696s audio file.
# Running inference.
# Inference took 1.138s for 1.992s audio file.
# Running inference.
# Inference took 1.730s for 2.952s audio file.
# Running inference.
# Inference took 2.092s for 3.192s audio file.
# Running inference.
# Inference took 2.256s for 3.840s audio file.
# Running inference.
# Inference took 3.360s for 5.760s audio file.
# Running inference.
# Inference took 2.944s for 4.680s audio file.
# Running inference.
# Inference took 2.726s for 4.392s audio file.
# Running inference.
# Inference took 2.357s for 3.960s audio file.
# Running inference.
# Inference took 2.834s for 5.112s audio file.
# Running inference.
# Inference took 2.578s for 4.512s audio file.
# Running inference.
# Inference took 2.296s for 3.912s audio file.
# Running inference.
# Inference took 2.438s for 4.200s audio file.
# Running inference.
# Inference took 2.991s for 5.184s audio file.
# Running inference.
# Inference took 1.748s for 3.048s audio file.
# Running inference.
# Inference took 2.481s for 4.392s audio file.
# Running inference.
# Inference took 2.780s for 5.040s audio file.
# Running inference.
# Inference took 2.456s for 4.224s audio file.
# Running inference.
# Inference took 2.128s for 3.840s audio file.
# Running inference.
# Inference took 1.310s for 2.280s audio file.
# Running inference.
# Inference took 3.630s for 6.552s audio file.
# Running inference.
# Inference took 2.060s for 3.792s audio file.
# Running inference.
# Inference took 2.229s for 3.960s audio file.
# Running inference.
# Inference took 1.380s for 2.472s audio file.
# Running inference.
# Inference took 2.133s for 3.792s audio file.
# Running inference.
# Inference took 2.895s for 4.992s audio file.
# Running inference.
# Inference took 1.369s for 2.496s audio file.
# Running inference.
# Inference took 1.899s for 3.456s audio file.
# Running inference.
# Inference took 2.266s for 4.104s audio file.
# Running inference.
# Inference took 1.651s for 2.952s audio file.
# Running inference.
# Inference took 2.082s for 3.744s audio file.
# Running inference.
# Inference took 2.211s for 3.960s audio file.
# Running inference.
# Inference took 4.252s for 7.680s audio file.
# Running inference.
# Inference took 2.350s for 4.200s audio file.
# Running inference.
# Inference took 2.068s for 3.744s audio file.
# Running inference.
# Inference took 2.353s for 4.176s audio file.
# Running inference.
# Inference took 3.128s for 5.688s audio file.
# Running inference.
# Inference took 3.686s for 6.648s audio file.
# Running inference.
# Inference took 4.967s for 8.712s audio file.
# Running inference.
# Inference took 4.059s for 7.272s audio file.
# Running inference.
# Inference took 1.713s for 3.072s audio file.
# Running inference.
# Inference took 3.086s for 5.376s audio file.
# Running inference.
# Inference took 2.436s for 4.320s audio file.
# Running inference.
# Inference took 2.832s for 4.992s audio file.
# Running inference.
# Inference took 1.339s for 2.400s audio file.
# Running inference.
# Inference took 1.701s for 3.000s audio file.
# Running inference.
# Inference took 2.062s for 3.600s audio file.
# Running inference.
# Inference took 1.504s for 2.592s audio file.
# Running inference.
# Inference took 1.524s for 2.712s audio file.
# Running inference.
# Inference took 1.869s for 3.312s audio file.
# Running inference.
# Inference took 2.937s for 5.160s audio file.
# Running inference.
# Inference took 2.304s for 4.032s audio file.
# Running inference.
# Inference took 2.854s for 5.040s audio file.
# Running inference.
# Inference took 4.470s for 7.896s audio file.
# Running inference.
# Inference took 2.687s for 4.800s audio file.
# Running inference.
# Inference took 3.179s for 5.568s audio file.
# Running inference.
# Inference took 1.488s for 2.640s audio file.
# Running inference.
# Inference took 1.925s for 3.360s audio file.
# Running inference.
# Inference took 2.458s for 4.632s audio file.
# Running inference.
# Inference took 2.086s for 3.600s audio file.
# Running inference.
# Inference took 2.433s for 4.200s audio file.
# Running inference.
# Inference took 1.252s for 2.232s audio file.
# Running inference.
# Inference took 1.373s for 2.400s audio file.
# Running inference.
# Inference took 2.489s for 4.320s audio file.
# Running inference.
# Inference took 2.203s for 3.912s audio file.
# Running inference.
# Inference took 1.348s for 2.400s audio file.
# Running inference.
# Inference took 3.072s for 5.400s audio file.
# Running inference.
# Inference took 3.162s for 5.712s audio file.
# Running inference.
# Inference took 2.666s for 4.800s audio file.
# Running inference.
# Inference took 2.582s for 4.632s audio file.
# Running inference.
# Inference took 3.429s for 6.000s audio file.
# Running inference.
# Inference took 1.977s for 3.672s audio file.
# Running inference.
# Inference took 2.839s for 5.112s audio file.
# Running inference.
# Inference took 3.132s for 5.544s audio file.
# Running inference.
# Inference took 2.712s for 4.824s audio file.
# Running inference.
# Inference took 2.478s for 4.464s audio file.
# Running inference.
# Inference took 3.191s for 5.760s audio file.
# Running inference.
# Inference took 1.765s for 3.072s audio file.
# Running inference.
# Inference took 2.816s for 5.112s audio file.
# Running inference.
# Inference took 3.259s for 5.712s audio file.
# Running inference.
# Inference took 4.247s for 7.296s audio file.
# Running inference.
# Inference took 2.879s for 5.064s audio file.
# Running inference.
# Inference took 2.542s for 4.656s audio file.
# Running inference.
# Inference took 1.732s for 3.120s audio file.
# Running inference.
# Inference took 2.286s for 4.056s audio file.
# Running inference.
# Inference took 2.387s for 4.320s audio file.
# Running inference.
# Inference took 2.769s for 4.872s audio file.
# Running inference.
# Inference took 2.406s for 4.320s audio file.
# Running inference.
# Inference took 1.871s for 3.432s audio file.
# Running inference.
# Inference took 1.933s for 3.360s audio file.
# Running inference.
# Inference took 1.820s for 3.240s audio file.
# Running inference.
# Inference took 1.986s for 3.600s audio file.
# Running inference.
# Inference took 3.044s for 5.232s audio file.
# Running inference.
# Inference took 2.270s for 3.960s audio file.
# Running inference.
# Inference took 2.795s for 4.872s audio file.
# Running inference.
# Inference took 3.580s for 6.240s audio file.
# Running inference.
# Inference took 3.419s for 5.880s audio file.
# Running inference.
# Inference took 3.202s for 5.712s audio file.
# Running inference.
# Inference took 3.239s for 5.592s audio file.
# Running inference.
# Inference took 4.130s for 7.080s audio file.
# Running inference.
# Inference took 4.714s for 8.112s audio file.
# Running inference.
# Inference took 2.767s for 5.112s audio file.
# Running inference.
# Inference took 2.159s for 3.840s audio file.
# Running inference.
# Inference took 2.383s for 4.200s audio file.
# Running inference.
# Inference took 2.486s for 4.392s audio file.
# Running inference.
# Inference took 2.447s for 4.272s audio file.
# Running inference.
# Inference took 3.020s for 5.400s audio file.
# Running inference.
# Inference took 1.735s for 3.072s audio file.
# Running inference.
# Inference took 3.182s for 5.520s audio file.
# Running inference.
# Inference took 5.465s for 9.552s audio file.
# Running inference.
# Inference took 2.029s for 3.504s audio file.
# Running inference.
# Inference took 2.240s for 3.936s audio file.
# Running inference.
# Inference took 1.539s for 2.736s audio file.
# Running inference.
# Inference took 2.319s for 4.104s audio file.
# Running inference.
# Inference took 2.980s for 5.256s audio file.
# Running inference.
# Inference took 2.037s for 3.624s audio file.
# Running inference.
# Inference took 2.233s for 3.960s audio file.
# Running inference.
# Inference took 1.895s for 3.432s audio file.
# Running inference.
# Inference took 1.874s for 3.480s audio file.
# Running inference.
# Inference took 2.116s for 3.672s audio file.
# Running inference.
# Inference took 3.340s for 5.832s audio file.
# Running inference.
# Inference took 2.098s for 3.600s audio file.
# Running inference.
# Inference took 1.920s for 3.312s audio file.
# Running inference.
# Inference took 1.689s for 2.952s audio file.
# Running inference.
# Inference took 2.320s for 4.032s audio file.
# Running inference.
# Inference took 2.523s for 4.272s audio file.
# Running inference.
# Inference took 2.501s for 4.320s audio file.
# Running inference.
# Inference took 2.127s for 3.792s audio file.
# Running inference.
# Inference took 1.981s for 3.480s audio file.
# Running inference.
# Inference took 1.908s for 3.240s audio file.
# Running inference.
# Inference took 2.174s for 3.912s audio file.
# Running inference.
# Inference took 2.275s for 3.960s audio file.
# Running inference.
# Inference took 2.182s for 3.600s audio file.
# Running inference.
# Inference took 1.837s for 3.120s audio file.
# Running inference.
# Inference took 3.525s for 6.168s audio file.
# Running inference.
# Inference took 3.093s for 5.352s audio file.
# Running inference.
# Inference took 1.438s for 2.400s audio file.
# Running inference.
# Inference took 1.359s for 2.352s audio file.
# Running inference.
# Inference took 2.871s for 5.040s audio file.
# Running inference.
# Inference took 1.725s for 3.072s audio file.
# Running inference.
# Inference took 2.749s for 4.752s audio file.
# Running inference.
# Inference took 2.074s for 3.600s audio file.
# Running inference.
# Inference took 2.496s for 4.320s audio file.
# Running inference.
# Inference took 1.730s for 3.072s audio file.
# Running inference.
# Inference took 2.475s for 4.200s audio file.
# Running inference.
# Inference took 2.298s for 4.080s audio file.
# Running inference.
# Inference took 1.862s for 3.480s audio file.
# Running inference.
# Inference took 2.117s for 3.792s audio file.
# Running inference.
# Inference took 1.999s for 3.672s audio file.
# Running inference.
# Inference took 2.481s for 4.416s audio file.
# Running inference.
# Inference took 1.934s for 3.456s audio file.
# Running inference.
# Inference took 3.461s for 6.000s audio file.
# Running inference.
# Inference took 2.124s for 3.840s audio file.
# Running inference.
# Inference took 2.995s for 5.304s audio file.
# Running inference.
# Inference took 2.030s for 3.552s audio file.
# Running inference.
# Inference took 1.937s for 3.528s audio file.
# Running inference.
# Inference took 1.214s for 2.232s audio file.
# Running inference.
# Inference took 1.665s for 2.952s audio file.
# Running inference.
# Inference took 2.497s for 4.320s audio file.
# Running inference.
# Inference took 1.912s for 3.240s audio file.
# Running inference.
# Inference took 2.147s for 3.792s audio file.
# Running inference.
# Inference took 2.327s for 4.152s audio file.
# Running inference.
# Inference took 2.830s for 4.920s audio file.
# Running inference.
# Inference took 1.930s for 3.360s audio file.
# Running inference.
# Inference took 2.121s for 3.720s audio file.
# Running inference.
# Inference took 2.125s for 3.792s audio file.
# Running inference.
# Inference took 1.911s for 3.360s audio file.
# Running inference.
# Inference took 1.945s for 3.432s audio file.
# Running inference.
# Inference took 1.568s for 2.712s audio file.
# Running inference.
# Inference took 3.858s for 6.552s audio file.
# Running inference.
# Inference took 2.817s for 4.992s audio file.
# Running inference.
# Inference took 2.794s for 4.872s audio file.
# Running inference.
# Inference took 1.384s for 2.448s audio file.
# Running inference.
# Inference took 1.892s for 3.384s audio file.
# Running inference.
# Inference took 2.468s for 4.320s audio file.
# Running inference.
# Inference took 3.035s for 5.160s audio file.
# Running inference.
# Inference took 2.082s for 3.600s audio file.
# Running inference.
# Inference took 3.301s for 5.664s audio file.
# Running inference.
# ...
# Running inference.
# Inference took 2.050s for 3.600s audio file.
# Running inference.
# Inference took 1.853s for 3.240s audio file.
# Running inference.
# Inference took 2.574s for 4.512s audio file.
# Running inference.
# Inference took 1.638s for 2.880s audio file.
# Running inference.
# Inference took 1.903s for 3.240s audio file.
# Running inference.
# Inference took 1.608s for 2.832s audio file.
# Running inference.
# Inference took 2.421s for 4.272s audio file.
# Running inference.
# Inference took 1.919s for 3.360s audio file.
# Running inference.
# Inference took 2.207s for 3.912s audio file.
# Running inference.
# Inference took 2.931s for 5.160s audio file.
# Running inference.
# Inference took 2.199s for 3.912s audio file.
# Running inference.
# Inference took 2.215s for 4.032s audio file.
# Running inference.
# Inference took 1.309s for 2.280s audio file.
# Running inference.
# Inference took 2.977s for 5.352s audio file.
# Running inference.
# Inference took 2.162s for 3.912s audio file.
# Running inference.
# Inference took 2.510s for 4.440s audio file.
# Running inference.
# Inference took 2.197s for 3.960s audio file.
# Running inference.
# Inference took 2.459s for 4.440s audio file.
# Running inference.
# Inference took 2.021s for 3.720s audio file.
# Running inference.
# Inference took 1.666s for 3.048s audio file.
# Running inference.
# Inference took 3.543s for 6.240s audio file.
# Running inference.
# Inference took 2.391s for 4.200s audio file.
# Running inference.
# Inference took 3.862s for 6.960s audio file.
# Running inference.
# Inference took 1.712s for 3.120s audio file.
# Running inference.
# Inference took 1.937s for 3.432s audio file.
# Running inference.
# Inference took 1.944s for 3.432s audio file.
# Running inference.
# Inference took 2.241s for 4.032s audio file.
# Running inference.
# Inference took 3.761s for 6.912s audio file.
# Running inference.
# Inference took 2.138s for 3.792s audio file.
# Running inference.
# Inference took 3.163s for 5.520s audio file.
# Running inference.
# Inference took 3.060s for 5.400s audio file.
# Running inference.
# Inference took 1.607s for 2.856s audio file.
# Running inference.
# Inference took 1.716s for 2.976s audio file.
# Running inference.
# Inference took 1.237s for 2.232s audio file.
# Running inference.
# Inference took 1.892s for 3.336s audio file.
# Running inference.
# Inference took 2.337s for 4.104s audio file.
# Running inference.
# Inference took 3.945s for 6.768s audio file.
# Running inference.
# Inference took 2.414s for 4.224s audio file.
# Running inference.
# Inference took 3.530s for 6.360s audio file.
# Running inference.
# Inference took 2.687s for 4.704s audio file.
# Running inference.
# Inference took 3.054s for 5.256s audio file.
# Running inference.
# Inference took 2.650s for 4.800s audio file.
# Running inference.
# Inference took 2.499s for 4.488s audio file.
# Running inference.
# Inference took 3.304s for 6.144s audio file.
# Running inference.
# Inference took 2.066s for 3.672s audio file.
# Running inference.
# Inference took 1.922s for 3.408s audio file.
# Running inference.
# Inference took 1.917s for 3.480s audio file.
# Running inference.
# Inference took 1.899s for 3.360s audio file.
# Running inference.
# Inference took 1.997s for 3.720s audio file.
# Running inference.
# Inference took 1.605s for 2.880s audio file.
# Running inference.
# Inference took 1.663s for 2.952s audio file.
# Running inference.
# Inference took 2.054s for 3.600s audio file.
# Running inference.
# Inference took 1.889s for 3.240s audio file.
# Running inference.
# Inference took 2.477s for 4.440s audio file.
# Running inference.
# Inference took 2.548s for 4.560s audio file.
# Running inference.
# Inference took 2.161s for 3.912s audio file.
# Running inference.
# Inference took 2.031s for 3.672s audio file.
# Running inference.
# Inference took 2.225s for 3.960s audio file.
# Running inference.
# Inference took 1.899s for 3.360s audio file.
# Running inference.
# Inference took 1.321s for 2.352s audio file.
# Running inference.
# Inference took 2.198s for 3.912s audio file.
# Running inference.
# Inference took 2.226s for 3.912s audio file.
# Running inference.
# Inference took 3.193s for 5.712s audio file.
# Running inference.
# Inference took 3.818s for 6.672s audio file.
# Running inference.
# Inference took 2.791s for 4.824s audio file.
# Running inference.
# Inference took 2.449s for 4.296s audio file.
# Running inference.
# Inference took 2.228s for 3.912s audio file.
# Running inference.
# Inference took 2.504s for 4.488s audio file.
# Running inference.
# Inference took 2.799s for 4.824s audio file.
# Running inference.
# Inference took 1.287s for 2.280s audio file.
# Running inference.
# Inference took 2.303s for 4.152s audio file.
# Running inference.
# Inference took 1.898s for 3.360s audio file.
# Running inference.
# Inference took 2.619s for 4.632s audio file.
# Running inference.
# Inference took 2.319s for 4.272s audio file.
# Running inference.
# Inference took 1.350s for 2.472s audio file.
# Running inference.
# Inference took 2.280s for 4.152s audio file.
# Running inference.
# Inference took 1.574s for 2.880s audio file.
# Running inference.
# Inference took 2.444s for 4.392s audio file.
# Running inference.
# Inference took 2.393s for 4.296s audio file.
# Running inference.
# Inference took 1.475s for 2.760s audio file.
# Running inference.
# Inference took 2.448s for 4.368s audio file.
# Running inference.
# Inference took 2.447s for 4.320s audio file.
# Running inference.
# Inference took 2.501s for 4.488s audio file.
# Running inference.
# Inference took 2.645s for 4.752s audio file.
# Running inference.
# Inference took 3.363s for 5.832s audio file.
# Running inference.
# Inference took 2.441s for 4.200s audio file.
# Running inference.
# Inference took 2.192s for 3.912s audio file.
# Running inference.
# Inference took 1.910s for 3.312s audio file.
# Running inference.
# Inference took 2.921s for 5.160s audio file.
# Running inference.
# Inference took 2.056s for 3.672s audio file.
# Running inference.
# Inference took 4.450s for 7.752s audio file.
# Running inference.
# Inference took 2.452s for 4.440s audio file.
# Running inference.
# Inference took 2.062s for 3.720s audio file.
# Running inference.
# Inference took 2.199s for 3.960s audio file.
# Running inference.
# Inference took 2.742s for 4.872s audio file.
# Running inference.
# Inference took 2.453s for 4.440s audio file.
# Running inference.
# Inference took 3.522s for 6.120s audio file.
# Running inference.
# Inference took 2.561s for 4.560s audio file.
# Running inference.
# Inference took 3.469s for 6.120s audio file.
# Running inference.
# Inference took 2.602s for 4.680s audio file.
# Running inference.
# Inference took 1.515s for 2.736s audio file.
# Running inference.
# Inference took 2.158s for 3.888s audio file.
# Running inference.
# Inference took 1.839s for 3.288s audio file.
# Running inference.
# Inference took 1.787s for 3.216s audio file.
# Running inference.
# Inference took 1.904s for 3.384s audio file.
# Running inference.
# Inference took 2.124s for 3.912s audio file.
# Running inference.
# Inference took 2.788s for 5.040s audio file.
# Running inference.
# Inference took 2.713s for 4.872s audio file.
# Running inference.
# Inference took 3.091s for 5.520s audio file.
# Running inference.
# Inference took 2.028s for 3.600s audio file.
# Running inference.
# Inference took 2.787s for 5.040s audio file.
# Running inference.
# Inference took 3.713s for 6.480s audio file.
# Running inference.
# Inference took 1.387s for 2.472s audio file.
# Running inference.
# Inference took 1.533s for 2.760s audio file.
# Running inference.
# Inference took 2.517s for 4.680s audio file.
# Running inference.
# Inference took 1.863s for 3.360s audio file.
# Running inference.
# Inference took 2.427s for 4.272s audio file.
# Running inference.
# Inference took 1.554s for 2.760s audio file.
# Running inference.
# Inference took 2.951s for 5.280s audio file.
# Running inference.
# Inference took 3.913s for 7.080s audio file.
# Running inference.
# Inference took 2.611s for 4.680s audio file.
# Running inference.
# Inference took 2.771s for 4.920s audio file.
# Running inference.
# Inference took 3.685s for 6.480s audio file.
# Running inference.
# Inference took 4.192s for 7.392s audio file.
# Running inference.
# Inference took 2.766s for 4.992s audio file.
# Running inference.
# Inference took 3.568s for 6.192s audio file.
# Running inference.
# Inference took 2.584s for 4.512s audio file.
# Running inference.
# Inference took 0.810s for 1.512s audio file.
# Running inference.
# Inference took 1.305s for 2.400s audio file.
# Running inference.
# Inference took 1.904s for 3.384s audio file.
# Running inference.
# Inference took 2.862s for 5.064s audio file.
# Running inference.
# Inference took 1.577s for 2.784s audio file.
# Running inference.
# Inference took 2.867s for 5.112s audio file.
# Running inference.
# Inference took 2.213s for 3.888s audio file.
# Running inference.
# Inference took 1.597s for 2.880s audio file.
# Running inference.
# Inference took 2.126s for 3.744s audio file.
# Running inference.
# Inference took 2.101s for 3.768s audio file.
# Running inference.
# Inference took 2.361s for 4.152s audio file.
# Running inference.
# Inference took 2.167s for 3.840s audio file.
# Running inference.
# Inference took 1.735s for 3.120s audio file.
# Running inference.
# Inference took 1.932s for 3.528s audio file.
# Running inference.
# Inference took 3.095s for 5.496s audio file.
# Running inference.
# Inference took 3.158s for 5.616s audio file.
# Running inference.
# Inference took 3.198s for 5.568s audio file.
# Running inference.
# Inference took 3.002s for 5.400s audio file.
# Running inference.
# Inference took 3.756s for 6.720s audio file.
# Running inference.
# Inference took 3.020s for 5.328s audio file.
# Running inference.
# Inference took 1.719s for 3.096s audio file.
# Running inference.
# Inference took 2.421s for 4.296s audio file.
# Running inference.
# Inference took 1.890s for 3.480s audio file.
# Running inference.
# Inference took 2.173s for 4.008s audio file.
# Running inference.
# Inference took 2.392s for 4.344s audio file.
# Running inference.
# Inference took 2.424s for 4.344s audio file.
# Running inference.
# Inference took 2.761s for 4.872s audio file.
# Running inference.
# Inference took 2.541s for 4.728s audio file.
# Running inference.
# Inference took 2.783s for 5.088s audio file.
# Running inference.
# Inference took 2.328s for 4.248s audio file.
# Running inference.
# Inference took 1.505s for 2.640s audio file.
# Running inference.
# Inference took 1.851s for 3.432s audio file.
# Running inference.
# Inference took 2.065s for 3.792s audio file.
# Running inference.
# Inference took 3.149s for 5.520s audio file.
# Running inference.
# Inference took 2.885s for 5.040s audio file.
# Running inference.
# Inference took 1.896s for 3.312s audio file.
# Running inference.
# Inference took 2.246s for 4.152s audio file.
# Running inference.
# Inference took 2.260s for 4.056s audio file.
# Running inference.
# Inference took 1.706s for 3.024s audio file.
# Running inference.
# Inference took 1.571s for 2.856s audio file.
# Running inference.
# Inference took 1.898s for 3.504s audio file.
# Running inference.
# Inference took 2.499s for 4.536s audio file.
# Running inference.
# Inference took 2.838s for 4.992s audio file.
# Running inference.
# Inference took 3.029s for 5.376s audio file.
# Running inference.
# Inference took 2.289s for 4.104s audio file.
# Running inference.
# Inference took 2.133s for 3.744s audio file.
# Running inference.
# Inference took 1.753s for 3.168s audio file.
# Running inference.
# Inference took 1.314s for 2.280s audio file.
# Running inference.
# Inference took 1.841s for 3.240s audio file.
# Running inference.
# Inference took 1.570s for 2.880s audio file.
# Running inference.
# Inference took 2.248s for 3.960s audio file.
# Running inference.
# Inference took 1.493s for 2.640s audio file.
# Running inference.
# Inference took 1.727s for 3.072s audio file.
# Running inference.
# Inference took 0.982s for 1.752s audio file.
# Running inference.
# Inference took 1.011s for 1.752s audio file.
# Running inference.
# Inference took 2.605s for 4.560s audio file.
# Running inference.
# Inference took 2.839s for 4.920s audio file.
# Running inference.
# Inference took 3.198s for 5.760s audio file.
# Running inference.
# Inference took 3.375s for 6.000s audio file.
# Running inference.
# Inference took 3.547s for 6.240s audio file.
# Running inference.
# Inference took 4.604s for 8.112s audio file.
# Running inference.
# Inference took 4.183s for 7.560s audio file.
# Running inference.
# Inference took 2.789s for 5.112s audio file.
# Running inference.
# Inference took 2.518s for 4.440s audio file.
# Running inference.
# Inference took 2.626s for 4.632s audio file.
# Running inference.
# Inference took 2.397s for 4.200s audio file.
# Running inference.
# Inference took 1.455s for 2.568s audio file.
# Running inference.
# Inference took 2.952s for 5.232s audio file.
# Running inference.
# Inference took 2.471s for 4.224s audio file.
# Running inference.
# Inference took 3.222s for 5.592s audio file.
# Running inference.
# Inference took 3.266s for 5.664s audio file.
# Running inference.
# Inference took 2.528s for 4.368s audio file.
# Running inference.
# Inference took 1.886s for 3.216s audio file.
# Running inference.
# Inference took 1.358s for 2.400s audio file.
# Running inference.
# Inference took 2.130s for 3.840s audio file.
# Running inference.
# Inference took 1.584s for 2.880s audio file.
# Running inference.
# Inference took 1.898s for 3.408s audio file.
# Running inference.
# Inference took 1.530s for 2.712s audio file.
# Running inference.
# Inference took 1.676s for 2.928s audio file.
# Running inference.
# Inference took 2.395s for 4.200s audio file.
# Running inference.
# Inference took 1.668s for 3.000s audio file.
# Running inference.
# Inference took 1.404s for 2.544s audio file.
# Running inference.
# Inference took 1.671s for 2.928s audio file.
# Running inference.
# Inference took 2.288s for 4.008s audio file.
# Running inference.
# Inference took 1.873s for 3.312s audio file.
# Running inference.
# Inference took 3.577s for 6.288s audio file.
# Running inference.
# Inference took 2.057s for 3.576s audio file.
# Running inference.
# Inference took 2.444s for 4.272s audio file.
# Running inference.
# Inference took 2.241s for 3.888s audio file.
# Running inference.
# Inference took 1.675s for 2.904s audio file.
# Running inference.
# Inference took 3.195s for 5.472s audio file.
# Running inference.
# Inference took 3.018s for 5.160s audio file.
# Running inference.
# Inference took 2.645s for 4.632s audio file.
# Running inference.
# Inference took 3.816s for 6.720s audio file.
# Running inference.
# Inference took 2.684s for 4.704s audio file.
# Running inference.
# Inference took 2.141s for 3.768s audio file.
# Running inference.
# Inference took 3.078s for 5.496s audio file.
# Running inference.
# Inference took 2.734s for 5.088s audio file.
# Running inference.
# Inference took 2.450s for 4.608s audio file.
# Running inference.
# Inference took 3.121s for 5.592s audio file.
# Running inference.
# Inference took 3.220s for 5.808s audio file.
# Running inference.
# Inference took 3.445s for 6.216s audio file.
# Running inference.
# Inference took 4.234s for 7.560s audio file.
# Running inference.
# Inference took 4.049s for 7.536s audio file.
# Running inference.
# Inference took 4.134s for 7.536s audio file.
# Running inference.
# Inference took 2.817s for 5.208s audio file.
# Running inference.
# Inference took 1.362s for 2.472s audio file.
# Running inference.
# Inference took 1.505s for 2.664s audio file.
# Running inference.
# Inference took 1.569s for 2.832s audio file.
# Running inference.
# Inference took 1.833s for 3.264s audio file.
# Running inference.
# Inference took 1.808s for 3.480s audio file.
# Running inference.
# Inference took 0.980s for 1.752s audio file.
# Running inference.
# Inference took 3.255s for 6.048s audio file.
# Running inference.
# Inference took 1.546s for 2.760s audio file.
# Running inference.
# Inference took 1.320s for 2.400s audio file.
# Running inference.
# Inference took 1.631s for 3.048s audio file.
# Running inference.
# Inference took 2.059s for 3.744s audio file.
# Running inference.
# Inference took 1.390s for 2.520s audio file.
# Running inference.
# Inference took 2.058s for 3.816s audio file.
# Running inference.
# Inference took 1.880s for 3.312s audio file.
# Running inference.
# Inference took 1.641s for 2.928s audio file.
# Running inference.
# Inference took 1.925s for 3.528s audio file.
# Running inference.
# Inference took 3.786s for 6.696s audio file.

# %%
print('testList: ', testList)
# Out:
# testList:  [24, 28, 53, 18, 22, 108, 44, 14, 44, 17, 39, 19, 24, 53, 32, 22, 15, 31, 42, 43, 107, 29, 33, 45, 49, 24, 63, 11, 64, 53, 58, 17, 52, 47, 1, 41, 6, 92, 21, 56, 34, 23, 34, 59, 71, 44, 30, 38, 18, 9, 14, 50, 29, 15, 43, 52, 16, 57, 36, 30, 23, 20, 60, 27, 23, 29, 12, 4, 47, 43, 29, 47, 50, 36, 63, 33, 37, 26, 28, 20, 22, 16, 53, 46, 41, 52, 49, 36, 40, 71, 26, 66, 17, 22, 30, 27, 23, 26, 43, 61, 35, 36, 35, 77, 23, 24, 49, 39, 22, 37, 26, 93, 33, 80, 30, 64, 29, 36, 15, 37, 89, 66, 25, 44, 29, 31, 31, 25, 33, 32, 33, 37, 32, 49, 38, 56, 48, 22, 12, 20, 14, 24, 64, 44, 42, 49, 22, 11, 26, 57, 22, 28, 60, 22, 28, 50, 
# %%
testBins = int(len(testList)/25)
devBins = int(len(devList)/25)
print('testBins: ', testBins)
print('devBins: ', devBins)

# %%
sns.distplot(testList, hist=True, kde=False, 
             bins=testBins, color = 'blue',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Test CSV')
plt.xlabel('Hamming Distance')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
print('Dev.csv')
print('Max :', max(devList))
print('Min :', min(devList))
print('Average :', round(mean(devList),2))
ctr = collections.Counter(devList)
print("Frequency of the elements in the List : ",ctr)
# Out:
# Dev.csv
# Max : 124
# Min : 0
# Average : 37.02
# Frequency of the elements in the List :  Counter({28: 61, 34: 48, 36: 48, 29: 46, 33: 42, 27: 42, 32: 40, 30: 40, 38: 40, 24: 38, 25: 38, 31: 37, 26: 37, 39: 36, 22: 35, 23: 34, 37: 34, 18: 33, 44: 33, 45: 33, 40: 33, 42: 32, 43: 32, 21: 32, 46: 32, 35: 31, 15: 30, 41: 28, 20: 27, 17: 24, 49: 24, 50: 24, 19: 23, 55: 22, 48: 21, 51: 20, 47: 19, 54: 18, 59: 17, 61: 17, 53: 15, 11: 14, 52: 14, 14: 13, 63: 13, 56: 13, 57: 13, 13: 13, 16: 12, 60: 12, 62: 12, 58: 9, 9: 9, 66: 9, 64: 8, 12: 8, 8: 8, 65: 8, 10: 8, 6: 7, 71: 7, 73: 7, 75: 6, 70: 6, 80: 5, 72: 5, 7: 5, 4: 4, 77: 4, 67: 4, 74: 4, 68: 4, 91: 4, 69: 4, 76: 3, 85: 3, 82: 3, 1: 2, 92: 2, 3: 2, 88: 2, 2: 2, 79: 2, 0: 2, 108: 1, 107: 1, 93: 1, 89: 1, 121: 1, 86: 1, 99: 1, 83: 1, 84: 1, 5: 1, 100: 1, 124: 1, 87: 1, 90: 1, 97: 1, 95: 1, 111: 1, 105: 1})

# %%
sns.distplot(devList, hist=True, kde=False, 
             bins=devBins, color = 'red',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('dev.csv')
plt.xlabel('Hamming Distance')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df = pd.DataFrame(list(zip(testList, devList)), 
               columns =['Test', 'Dev']) 
df
# Out:
#       Test  Dev
# 0       24   24
# 1       28   28
# 2       53   53
# 3       18   18
# 4       22   22
# ...    ...  ...
# 1624    36   36
# 1625    50   50
# 1626    36   36
# 1627     4    4
# 1628    63   63
#
# [1629 rows x 2 columns]

# %%
count = df['Test'].value_counts() 
print(count)
# Out:
# 28     61
# 36     48
# 34     48
# 29     46
# 27     42
#        ..
# 87      1
# 86      1
# 84      1
# 83      1
# 124     1
# Name: Test, Length: 102, dtype: int64

# %%
count = df['Dev'].value_counts() 
print(count)
# Out:
# 28     61
# 36     48
# 34     48
# 29     46
# 27     42
#        ..
# 87      1
# 86      1
# 84      1
# 83      1
# 124     1
# Name: Dev, Length: 102, dtype: int64

# %%
df.to_csv("/home/fakrul/Model_Mozilla_CommonDataSet"+"/test_dev_inference.csv", index=False)
print('test_dev_inference.csv is created')
